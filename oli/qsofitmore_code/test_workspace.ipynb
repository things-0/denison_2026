# %%
from dustmaps.config import config
config['data_dir'] = '/Users/o_thorp/Downloads/my_stuff/Uni/other/scholarships/denison_2026/oli/qsofitmore_code/data/dust_maps'

# import dustmaps.sfd
# dustmaps.sfd.fetch()
