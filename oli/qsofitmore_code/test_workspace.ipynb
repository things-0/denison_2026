# %%
# from dustmaps.config import config
# config['data_dir'] = '/Users/o_thorp/Downloads/my_stuff/Uni/other/scholarships/denison_2026/oli/qsofitmore/data/dust_maps'

# import dustmaps.sfd
# dustmaps.sfd.fetch()
# Out:
# ...
#   0.0 B of 64.0 MiB |   0.0 s/B |                       |   0% | ETA:  --:--:--
#  17.0 KiB of 64.0 MiB | 150.3 KiB/s |                   |   0% | ETA:   0:07:15
#  68.0 KiB of 64.0 MiB | 216.2 KiB/s |                   |   0% | ETA:   0:05:02
# 170.0 KiB of 64.0 MiB | 335.3 KiB/s |                   |   0% | ETA:   0:03:14
# 272.0 KiB of 64.0 MiB | 387.5 KiB/s |                   |   0% | ETA:   0:02:48
# 442.0 KiB of 64.0 MiB | 492.1 KiB/s |                   |   0% | ETA:   0:02:12
# 748.0 KiB of 64.0 MiB | 650.4 KiB/s |                   |   1% | ETA:   0:01:39
# 986.0 KiB of 64.0 MiB | 763.6 KiB/s |                   |   1% | ETA:   0:01:24
#   1.2 MiB of 64.0 MiB | 822.8 KiB/s |                   |   1% | ETA:   0:01:18
#   1.7 MiB of 64.0 MiB |   1.0 MiB/s |                   |   2% | ETA:   0:01:00
#   2.3 MiB of 64.0 MiB |   1.2 MiB/s |                   |   3% | ETA:   0:00:49
#   3.2 MiB of 64.0 MiB |   1.2 MiB/s |                   |   5% | ETA:   0:00:49
# ...
