# %% [markdown]
# ## Before you start working

# %%
git checkout master
git pull
git checkout shaun-code # or oliver-code
git merge master

# %% [markdown]
# ## Make some <span style="color: red;">changes</span> to your files. <span style="color: red;">Then</span> to save:

# %% [markdown]
# Make sure you're on your own branch, not master

# %%
git add < filenames > # or just . for everything
git commit -m "Describe what you changed"
# git push -u origin shaun-code   # first time only
git push                          # after that

# %% [markdown]
# ## When you're ready to share/finish

# %%
git checkout master
git pull
git merge shaun-code # or oliver-code

# %% [markdown]
# If you get a weird vim text editor asking how you want to merge the changes, try typing `:wq` then enter. If this does not work, then make a manual copy of all your work and dw about git until we find a way to fix it...

# %%
# git push -u origin master   # first time only
git push
